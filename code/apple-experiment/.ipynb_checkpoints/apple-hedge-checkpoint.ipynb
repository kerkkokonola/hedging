# %%
# Install needed stuff to the Jupyter and kernel environment
# Need to install only once, so commented out for cleaner output
# %pip install pyarrow
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install pyfinance
# %pip install yfinance
# %pip install yahoo-fin

# %%
# Import needed stuff
import sys
import pyarrow.feather as feather
import math
import pandas
import numpy as np
import matplotlib.pyplot as plt
from pyfinance.options import BSM
import yfinance as yf
from datetime import datetime, timedelta, date
from yahoo_fin import options as op

# %% [markdown]
# # Hedging assigment

# %% [markdown]
# # Fetch SP500 index and option data via ```yfinance```

# %% [markdown]
# ### Data fetching and wrangling

# %%
# Get data from Yahoo Finance
def get_historical_data_and_option_expirations(ticker):
    ticker_data = yf.Ticker(ticker)
    
    # Get expiration dates of the options to a dataframe
    expiration_dates = pandas.DataFrame(data=ticker_data.options)
    
    return ticker_data, expiration_dates

# %%
def get_option_chain_by_expiration(data, expiration_date):
    # Get the option chain for the data
    option_chain_for_expiration = data.option_chain(expiration_date)
    
    # We will use call options for the hedging assignment, construct them to a dataframe
    opt_calls = pandas.DataFrame(option_chain_for_expiration.calls)
    
    # Get also the Put options and construct them to a dataframe
    # Optional and not needed yet in the assignment
    opt_puts = pandas.DataFrame(option_chain_for_expiration.puts)

    return opt_calls, opt_puts

# %%
def write_dataframes_to_csv(df, file_name):
    df.to_csv(str(file_name) + '.csv', sep='\t', index=True)

# %%
# SPY stands for Standard & Poors

# Dataframe of historical data, list of expiration dates
ticker, option_expirations = get_historical_data_and_option_expirations('SPY')

# Historical data as DataFrame
df_history = pandas.DataFrame(ticker.history(period='max'))

# Take the first option, which expires
option_expiration_date = option_expirations.iloc[0][0]
print(option_expiration_date)

# Dataframe of calls and dataframe of puts for a single expiration date
calls, puts = get_option_chain_by_expiration(ticker, option_expiration_date)
# Out:
# 2023-11-17

# %%
write_dataframes_to_csv(df_history, 'historical_data_all')
write_dataframes_to_csv(calls, 'calls_1')
write_dataframes_to_csv(puts, 'puts_1')

# %%
print(calls)
# print(df_history)
# print(option_expiration_date)
prices_after_hedge_date = df_history['2023-10-02':'2023-11-16']
print(prices_after_hedge_date)

# %% [markdown]
# ## The hedging function itself

# %%
def delta_hedge(underlying_data, call_option_data, option_expiration_date):
    # print(underlying_data)
    # print(call_option_data)
    # print(option_expiration_date)
    
    # Get time to maturity in years
    t = 46/365 # Comes from the option expiration date counted backwards
    # Debug print
    print(t)

    # t = 0 is 2.10.
    t0 = '2023-10-02'

    # US treasury 3-Month Treasury Yield, Level from FRED for Q2/2023
    r = 0.05076
    
    initial_call = BSM(kind='call', S0=underlying_data.iloc[0]['Close'], K=call_option_data.iloc[0]['strike'], T=t, r=r, sigma=call_option_data.iloc[0]['impliedVolatility'])
    print('Initial call option value from BSM', initial_call.value()) # Value of the BSM for the call option c0 at time t0

    initial_delta = initial_call.delta() # Delta of the BSM for the call option c0 at time t0
    print('Initial value of delta from BSM', initial_delta)

    scraped_data = call_option_data[['strike', 'impliedVolatility']]
    scraped_strike_prices_close_to_atm = scraped_data.iloc[100:110]
    print(scraped_strike_prices_close_to_atm)
    for entry in underlying_data['Close']:
        for index, row in scraped_strike_prices_close_to_atm.iterrows():
            call = BSM(kind='call', S0=entry, K=row["strike"], T=t, r=r, sigma=row['impliedVolatility'])
            print('Call option value from BSM', call.value()) # Value of the BSM for the call option c at time t
        
            delta = call.delta() # Delta of the BSM for the call option c at time t
            print('Value of delta from BSM', delta)
            print('\n')

# %%
delta_hedge(prices_after_hedge_date, calls, option_expiration_date)
# Out:
# 0.12602739726027398
# Initial call option value from BSM 218.6491113792123
# Initial value of delta from BSM 1.0
#      strike  impliedVolatility
# 100   447.0           0.000010
# 101   448.0           0.000010
# 102   449.0           0.000010
# 103   450.0           0.000010
# 104   451.0           0.007822
# 105   452.0           0.015635
# 106   453.0           0.031260
# 107   454.0           0.031260
# 108   455.0           0.062509
# 109   456.0           0.062509
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 3.309650851340792e-67
# Value of delta from BSM 4.809438649973801e-66
#
#
# Call option value from BSM 4.0033264355868827e-20
# Value of delta from BSM 1.5505168189142523e-19
#
#
# Call option value from BSM 1.3480123945737313e-06
# Value of delta from BSM 1.4417553104609848e-06
#
#
# Call option value from BSM 4.841307689617982e-07
# Value of delta from BSM 5.367825969959922e-07
#
#
# Call option value from BSM 0.017194835058967683
# Value of delta from BSM 0.005702409569032781
#
#
# Call option value from BSM 0.012572255173565194
# Value of delta from BSM 0.004282126559362274
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.2356644647914318e-108
# Value of delta from BSM 2.3295177693210485e-107
#
#
# Call option value from BSM 4.578221538234836e-31
# Value of delta from BSM 2.2637272179464126e-30
#
#
# Call option value from BSM 1.423613565904617e-09
# Value of delta from BSM 1.8923322162127794e-09
#
#
# Call option value from BSM 4.0691238511470965e-10
# Value of delta from BSM 5.573913352271064e-10
#
#
# Call option value from BSM 0.002170324858922823
# Value of delta from BSM 0.0008524489307270126
#
#
# Call option value from BSM 0.0015055979015885512
# Value of delta from BSM 0.0006055163433267412
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 4.577250177604549e-85
# Value of delta from BSM 7.557356706255147e-84
#
#
# Call option value from BSM 7.311848402219225e-25
# Value of delta from BSM 3.19028315783095e-24
#
#
# Call option value from BSM 6.776060818653937e-08
# Value of delta from BSM 8.049561479161101e-08
#
#
# Call option value from BSM 2.191405506889555e-08
# Value of delta from BSM 2.6906586195836636e-08
#
#
# Call option value from BSM 0.006883849299125666
# Value of delta from BSM 0.0024741736852114103
#
#
# Call option value from BSM 0.004913647078925942
# Value of delta from BSM 0.001811145755120644
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 3.22926426450425e-86
# Value of delta from BSM 5.370730881322021e-85
#
#
# Call option value from BSM 3.6290760604176717e-25
# Value of delta from BSM 1.594293828225363e-24
#
#
# Call option value from BSM 5.599854454630638e-08
# Value of delta from BSM 6.692934209985371e-08
#
#
# Call option value from BSM 1.799490372255247e-08
# Value of delta from BSM 2.2225823069569565e-08
#
#
# Call option value from BSM 0.0064982527792973865
# Value of delta from BSM 0.002346681622932367
#
#
# Call option value from BSM 0.00463159981164829
# Value of delta from BSM 0.0017151510884596633
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 6.298814609164492e-54
# Value of delta from BSM 8.123181767284481e-53
#
#
# Call option value from BSM 1.436372923061179e-16
# Value of delta from BSM 4.983290409867228e-16
#
#
# Call option value from BSM 1.3133682484097256e-05
# Value of delta from BSM 1.2774132550538467e-05
#
#
# Call option value from BSM 5.144338039866393e-06
# Value of delta from BSM 5.201938923485253e-06
#
#
# Call option value from BSM 0.0351210425948425
# Value of delta from BSM 0.01085272277363747
#
#
# Call option value from BSM 0.026192320207065745
# Value of delta from BSM 0.00832345879241542
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.0378533133033499e-39
# Value of delta from BSM 1.1331821782546042e-38
#
#
# Call option value from BSM 1.0210669863370851e-12
# Value of delta from BSM 3.045920940316577e-12
#
#
# Call option value from BSM 0.00016233311548734253
# Value of delta from BSM 0.00013908484840024845
#
#
# Call option value from BSM 7.061307101610334e-05
# Value of delta from BSM 6.315912208157027e-05
#
#
# Call option value from BSM 0.07914743186863937
# Value of delta from BSM 0.022327006309959287
#
#
# Call option value from BSM 0.06044620155420333
# Value of delta from BSM 0.01756613645732887
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 8.095294159533603e-30
# Value of delta from BSM 7.555434913061582e-29
#
#
# Call option value from BSM 5.418146413866812e-10
# Value of delta from BSM 1.4062861772692825e-09
#
#
# Call option value from BSM 0.0010061852685002148
# Value of delta from BSM 0.0007700424538507648
#
#
# Call option value from BSM 0.0004759097549971725
# Value of delta from BSM 0.00038171257321638325
#
#
# Call option value from BSM 0.1457734961277346
# Value of delta from BSM 0.03803484128682258
#
#
# Call option value from BSM 0.1134536453360937
# Value of delta from BSM 0.030541656312133056
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 4.422277154212423e-23
# Value of delta from BSM 3.582564099309475e-22
#
#
# Call option value from BSM 4.20893382400636e-08
# Value of delta from BSM 9.66468168218772e-08
#
#
# Call option value from BSM 0.0036904585791044386
# Value of delta from BSM 0.0025658218125144405
#
#
# Call option value from BSM 0.0018622361193654235
# Value of delta from BSM 0.0013616648676270699
#
#
# Call option value from BSM 0.22860638527671995
# Value of delta from BSM 0.05594605804897512
#
#
# Call option value from BSM 0.18053241987187008
# Value of delta from BSM 0.04564065396141489
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.6735694331131748e-33
# Value of delta from BSM 1.6651284647065997e-32
#
#
# Call option value from BSM 5.166566245947368e-11
# Value of delta from BSM 1.4186993242174024e-10
#
#
# Call option value from BSM 0.0005051745960707732
# Value of delta from BSM 0.00040450002336308845
#
#
# Call option value from BSM 0.00023129606638661038
# Value of delta from BSM 0.00019378911736969768
#
#
# Call option value from BSM 0.11545153927036722
# Value of delta from BSM 0.031068810176068228
#
#
# Call option value from BSM 0.08919828951279385
# Value of delta from BSM 0.024750909656719708
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.4908162502313833e-43
# Value of delta from BSM 1.7117960435519083e-42
#
#
# Call option value from BSM 9.159519443903255e-14
# Value of delta from BSM 2.859063001648313e-13
#
#
# Call option value from BSM 8.14372735307746e-05
# Value of delta from BSM 7.24488749360661e-05
#
#
# Call option value from BSM 3.4382220983394246e-05
# Value of delta from BSM 3.189165125990818e-05
#
#
# Call option value from BSM 0.06314620804864202
# Value of delta from BSM 0.018294201007550748
#
#
# Call option value from BSM 0.0479010560530142
# Value of delta from BSM 0.014289018537069589
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 4.45485800575492e-24
# Value of delta from BSM 3.694676244959502e-23
#
#
# Call option value from BSM 2.1984351106070174e-08
# Value of delta from BSM 5.1505933678389204e-08
#
#
# Call option value from BSM 0.0030330176883404114
# Value of delta from BSM 0.0021417146610847883
#
#
# Call option value from BSM 0.0015151323703011532
# Value of delta from BSM 0.0011245470086579815
#
#
# Call option value from BSM 0.2133911783297684
# Value of delta from BSM 0.05275877431211876
#
#
# Call option value from BSM 0.16813504228771592
# Value of delta from BSM 0.042934360273404235
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 3.7728229451100685e-24
# Value of delta from BSM 3.1342223958516206e-23
#
#
# Call option value from BSM 2.0976332818804306e-08
# Value of delta from BSM 4.9214358568756295e-08
#
#
# Call option value from BSM 0.002990419863351579
# Value of delta from BSM 0.00211396643544471
#
#
# Call option value from BSM 0.001492774103737493
# Value of delta from BSM 0.0011091307351161579
#
#
# Call option value from BSM 0.21233719907677084
# Value of delta from BSM 0.05253644621854045
#
#
# Call option value from BSM 0.16727740431890936
# Value of delta from BSM 0.042745874870338076
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 3.026707740270453e-50
# Value of delta from BSM 3.7563064278740306e-49
#
#
# Call option value from BSM 1.4103126212674543e-15
# Value of delta from BSM 4.724090309628168e-15
#
#
# Call option value from BSM 2.4958753230306524e-05
# Value of delta from BSM 2.3561464215241585e-05
#
#
# Call option value from BSM 1.0031346104810365e-05
# Value of delta from BSM 9.85459039922598e-06
#
#
# Call option value from BSM 0.043103182694445685
# Value of delta from BSM 0.013032236769869048
#
#
# Call option value from BSM 0.032334030596909535
# Value of delta from BSM 0.010057892309860424
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 6.941705781920275e-73
# Value of delta from BSM 1.0540605964182417e-71
#
#
# Call option value from BSM 1.2341821553396871e-21
# Value of delta from BSM 4.9794254556384956e-21
#
#
# Call option value from BSM 5.170189730017538e-07
# Value of delta from BSM 5.731054348650375e-07
#
#
# Call option value from BSM 1.7936753682147913e-07
# Value of delta from BSM 2.0590069046417022e-07
#
#
# Call option value from BSM 0.01279128087653203
# Value of delta from BSM 0.004358688974283175
#
#
# Call option value from BSM 0.009278731005935237
# Value of delta from BSM 0.003245637507272097
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 6.167911700066244e-112
# Value of delta from BSM 1.1818536253443836e-110
#
#
# Call option value from BSM 6.238563531431533e-32
# Value of delta from BSM 3.132610775628041e-31
#
#
# Call option value from BSM 8.334057603288068e-10
# Value of delta from BSM 1.1234079330566224e-09
#
#
# Call option value from BSM 2.3437540885185614e-10
# Value of delta from BSM 3.2545740455486873e-10
#
#
# Call option value from BSM 0.0018531422638740636
# Value of delta from BSM 0.0007360892065303585
#
#
# Call option value from BSM 0.0012807293468560799
# Value of delta from BSM 0.000520796992186978
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 4.222396308541277e-118
# Value of delta from BSM 8.329750457395572e-117
#
#
# Call option value from BSM 1.5163958829008114e-33
# Value of delta from BSM 7.827899498897293e-33
#
#
# Call option value from BSM 3.0764862981388784e-10
# Value of delta from BSM 4.252731013400272e-10
#
#
# Call option value from BSM 8.398495181346143e-11
# Value of delta from BSM 1.1952105103536588e-10
#
#
# Call option value from BSM 0.0013825690925723388
# Value of delta from BSM 0.000560440000758909
#
#
# Call option value from BSM 0.0009489383238498739
# Value of delta from BSM 0.00039365814255857813
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.2612753212644287e-92
# Value of delta from BSM 2.1808041888316473e-91
#
#
# Call option value from BSM 7.397362862360267e-27
# Value of delta from BSM 3.3706931860703715e-26
#
#
# Call option value from BSM 1.9458419001834275e-08
# Value of delta from BSM 2.4028523216388076e-08
#
#
# Call option value from BSM 6.038919643497563e-09
# Value of delta from BSM 7.699531820042112e-09
#
#
# Call option value from BSM 0.0047270355485761195
# Value of delta from BSM 0.001751228118982028
#
#
# Call option value from BSM 0.0033422473994901836
# Value of delta from BSM 0.0012691383387024122
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.7938855727563718e-144
# Value of delta from BSM 3.9491681174811914e-143
#
#
# Call option value from BSM 1.9881883774303773e-40
# Value of delta from BSM 1.139530911996405e-39
#
#
# Call option value from BSM 4.502216148061527e-12
# Value of delta from BSM 6.850751239083183e-12
#
#
# Call option value from BSM 1.0906035644657352e-12
# Value of delta from BSM 1.7045949728225272e-12
#
#
# Call option value from BSM 0.0004050897653557345
# Value of delta from BSM 0.00017763986462617233
#
#
# Call option value from BSM 0.00027039693538722515
# Value of delta from BSM 0.00012118855749716102
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.2185007883828145e-196
# Value of delta from BSM 3.1751881130298897e-195
#
#
# Call option value from BSM 5.818598559535032e-54
# Value of delta from BSM 3.9216187393163417e-53
#
#
# Call option value from BSM 1.2078705280607073e-15
# Value of delta from BSM 2.137359556700559e-15
#
#
# Call option value from BSM 2.374334715647251e-16
# Value of delta from BSM 4.3016342294470845e-16
#
#
# Call option value from BSM 3.902596903621047e-05
# Value of delta from BSM 1.943270287391571e-05
#
#
# Call option value from BSM 2.4801966307805984e-05
# Value of delta from BSM 1.259701389663016e-05
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.9734387255597723e-218
# Value of delta from BSM 5.448322138392606e-217
#
#
# Call option value from BSM 1.3629182759120377e-59
# Value of delta from BSM 9.713192903431072e-59
#
#
# Call option value from BSM 4.039068151232655e-17
# Value of delta from BSM 7.532742131374922e-17
#
#
# Call option value from BSM 7.335240596933321e-18
# Value of delta from BSM 1.3991683586967456e-17
#
#
# Call option value from BSM 1.5053835522181938e-05
# Value of delta from BSM 7.842259925389055e-06
#
#
# Call option value from BSM 9.389631958226907e-06
# Value of delta from BSM 4.985987997741199e-06
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 7.063252449436425e-164
# Value of delta from BSM 1.6656793770699194e-162
#
#
# Call option value from BSM 1.7941214189325622e-45
# Value of delta from BSM 1.0983985730910593e-44
#
#
# Call option value from BSM 2.077248945412609e-13
# Value of delta from BSM 3.3600279251820385e-13
#
#
# Call option value from BSM 4.63861642782218e-14
# Value of delta from BSM 7.696517604936541e-14
#
#
# Call option value from BSM 0.00016770746690362992
# Value of delta from BSM 7.738835199719364e-05
#
#
# Call option value from BSM 0.00010983034959629115
# Value of delta from BSM 5.1755952851898256e-05
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 2.487737760431178e-138
# Value of delta from BSM 5.348524174148263e-137
#
#
# Call option value from BSM 7.913152626729201e-39
# Value of delta from BSM 4.433910165879795e-38
#
#
# Call option value from BSM 1.1982473668111163e-11
# Value of delta from BSM 1.785630162677898e-11
#
#
# Call option value from BSM 2.9815466452064868e-12
# Value of delta from BSM 4.566017679022986e-12
#
#
# Call option value from BSM 0.0005373862452479616
# Value of delta from BSM 0.00023162460728502694
#
#
# Call option value from BSM 0.0003609612216653735
# Value of delta from BSM 0.00015905674518450053
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 4.584447143988473e-100
# Value of delta from BSM 8.265861905218174e-99
#
#
# Call option value from BSM 8.145040062884075e-29
# Value of delta from BSM 3.860979685723584e-28
#
#
# Call option value from BSM 5.747951663414191e-09
# Value of delta from BSM 7.3545349954988845e-09
#
#
# Call option value from BSM 1.7156085986602234e-09
# Value of delta from BSM 2.2643281267110144e-09
#
#
# Call option value from BSM 0.003283271884476302
# Value of delta from BSM 0.0012509540475469996
#
#
# Call option value from BSM 0.00230060801162546
# Value of delta from BSM 0.0008980066581487705
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 2.500525424807472e-47
# Value of delta from BSM 3.00402984409043e-46
#
#
# Call option value from BSM 8.665139883077277e-15
# Value of delta from BSM 2.817901009921275e-14
#
#
# Call option value from BSM 4.1680551691423984e-05
# Value of delta from BSM 3.8375841729808675e-05
#
#
# Call option value from BSM 1.7108521395362702e-05
# Value of delta from BSM 1.640533197353178e-05
#
#
# Call option value from BSM 0.05082572579858535
# Value of delta from BSM 0.015091757483014933
#
#
# Call option value from BSM 0.038309734027767384
# Value of delta from BSM 0.011707177372706894
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 3.2568576732224335e-29
# Value of delta from BSM 3.005599445591347e-28
#
#
# Call option value from BSM 7.981713439467179e-10
# Value of delta from BSM 2.05132497329291e-09
#
#
# Call option value from BSM 0.0011280707063697215
# Value of delta from BSM 0.0008565710270087255
#
#
# Call option value from BSM 0.0005365071264012977
# Value of delta from BSM 0.00042707010145374654
#
#
# Call option value from BSM 0.15157585807946816
# Value of delta from BSM 0.039339028279382654
#
#
# Call option value from BSM 0.11811604573913925
# Value of delta from BSM 0.0316314175946125
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 2.3433371367834286e-25
# Value of delta from BSM 2.000002635762718e-24
#
#
# Call option value from BSM 9.583929177766297e-09
# Value of delta from BSM 2.301450939167358e-08
#
#
# Call option value from BSM 0.002363201075912147
# Value of delta from BSM 0.0017010426941060036
#
#
# Call option value from BSM 0.0011656808446073863
# Value of delta from BSM 0.0008813108801061186
#
#
# Call option value from BSM 0.19559364618331188
# Value of delta from BSM 0.048976462846537325
#
#
# Call option value from BSM 0.15367376640122288
# Value of delta from BSM 0.03973313959998465
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 5.4503027678956e-21
# Value of delta from BSM 4.187931979678317e-20
#
#
# Call option value from BSM 1.6561026249439694e-07
# Value of delta from BSM 3.635662318828777e-07
#
#
# Call option value from BSM 0.005599447349795339
# Value of delta from BSM 0.0037614901858832755
#
#
# Call option value from BSM 0.002887887094223718
# Value of delta from BSM 0.0020428719335441833
#
#
# Call option value from BSM 0.2649714013300226
# Value of delta from BSM 0.06340657463062176
#
#
# Call option value from BSM 0.21028016856105225
# Value of delta from BSM 0.05200442939667122
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 6.153940198386381e-20
# Value of delta from BSM 4.594509587640703e-19
#
#
# Call option value from BSM 3.315348024539029e-07
# Value of delta from BSM 7.103888692365733e-07
#
#
# Call option value from BSM 0.006928749520252575
# Value of delta from BSM 0.004569806592738403
#
#
# Call option value from BSM 0.003614351447455144
# Value of delta from BSM 0.0025120003871395733
#
#
# Call option value from BSM 0.2859296955214923
# Value of delta from BSM 0.06761419273260412
#
#
# Call option value from BSM 0.22749390680168702
# Value of delta from BSM 0.055610437877516544
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 9.918705811608902e-33
# Value of delta from BSM 9.743237244823763e-32
#
#
# Call option value from BSM 8.445834677671438e-11
# Value of delta from BSM 2.2930719305066203e-10
#
#
# Call option value from BSM 0.0005831071890032846
# Value of delta from BSM 0.0004626558205864918
#
#
# Call option value from BSM 0.00026876609785315975
# Value of delta from BSM 0.00022320637896391772
#
#
# Call option value from BSM 0.12116296288407113
# Value of delta from BSM 0.0324016517251763
#
#
# Call option value from BSM 0.09375201683585033
# Value of delta from BSM 0.025854768385767946
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.0936072330644773e-10
# Value of delta from BSM 5.717214033625859e-10
#
#
# Call option value from BSM 0.0001789884416288634
# Value of delta from BSM 0.00028775999600641884
#
#
# Call option value from BSM 0.05151395768831968
# Value of delta from BSM 0.027620174342179886
#
#
# Call option value from BSM 0.03017306634026884
# Value of delta from BSM 0.01718582102000941
#
#
# Call option value from BSM 0.6028569077163155
# Value of delta from BSM 0.12531101345674983
#
#
# Call option value from BSM 0.49233700641060096
# Value of delta from BSM 0.10605742143724944
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 0.0
# Value of delta from BSM 0.0
#
#
# Call option value from BSM 1.14907510726276e-11
# Value of delta from BSM 6.322197033628163e-11
#
#
# Call option value from BSM 8.988164877500593e-05
# Value of delta from BSM 0.00015034189337024097
#
#
# Call option value from BSM 0.04099902506148645
# Value of delta from BSM 0.022593184324959693
#
#
# Call option value from BSM 0.02367817813837725
# Value of delta from BSM 0.013846115406042935
#
#
# Call option value from BSM 0.5520584954660563
# Value of delta from BSM 0.11666710533360986
#
#
# Call option value from BSM 0.4494179034064203
# Value of delta from BSM 0.09839599955059464
#
#
# Call option value from BSM 4.5804104045018335
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 3.586787136981002
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 2.5931638694601133
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 1.5995406019392249
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 0.8574268967304306
# Value of delta from BSM 0.6872114079014462
#
#
# Call option value from BSM 0.812206109969452
# Value of delta from BSM 0.4392690493621217
#
#
# Call option value from BSM 1.374820191376017
# Value of delta from BSM 0.3930348050596768
#
#
# Call option value from BSM 1.0255624692125593
# Value of delta from BSM 0.3191340894971907
#
#
# Call option value from BSM 2.5274458928278705
# Value of delta from BSM 0.37223990809026786
#
#
# Call option value from BSM 2.184127479340418
# Value of delta from BSM 0.33547006150515873
#
#
# Call option value from BSM 5.5303920939549585
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 4.536768826434127
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 3.5431455589132383
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 2.54952229139235
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 1.619208139695786
# Value of delta from BSM 0.8942605308209213
#
#
# Call option value from BSM 1.3014155818765971
# Value of delta from BSM 0.5902525519795119
#
#
# Call option value from BSM 1.7835141060224373
# Value of delta from BSM 0.4677812974405282
#
#
# Call option value from BSM 1.3619643642366555
# Value of delta from BSM 0.38991065084393917
#
#
# Call option value from BSM 2.8983632408697417
# Value of delta from BSM 0.4088024358255309
#
#
# Call option value from BSM 2.5195363273980718
# Value of delta from BSM 0.37086696712691736
#
#
# Call option value from BSM 6.0804104045018335
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 5.086787136981002
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 4.093163869460113
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 3.099540601939225
# Value of delta from BSM 1.0
#
#
# Call option value from BSM 2.1293868897016637
# Value of delta from BSM 0.9544566693687004
#
#
# Call option value from BSM 1.6491299671343995
# Value of delta from BSM 0.6730776601317874
#
#
# Call option value from BSM 2.052874064406069
# Value of delta from BSM 0.5116886714261448
#
#
# Call option value from BSM 1.5881549534808244
# Value of delta from BSM 0.43274090644130936
#
#
# Call option value from BSM 3.1291216571401037
# Value of delta from BSM 0.43032688502160266
#
#
# Call option value from BSM 2.7292785118733036
# Value of delta from BSM 0.39186042062896453
