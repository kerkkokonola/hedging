# %% [markdown]
# # Install packages via PIP

# %%
# Install needed stuff to the Jupyter and kernel environment
# Need to install only once, so commented out for cleaner output
# %pip install pyarrow
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install pyfinance
# %pip install yfinance
# %pip install yahoo-fin
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in /home/aleksi/.local/lib/python3.10/site-packages (14.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/aleksi/.local/lib/python3.10/site-packages (from pyarrow) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/aleksi/.local/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/aleksi/.local/lib/python3.10/site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/aleksi/.local/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyfinance in /home/aleksi/.local/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: seaborn in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (0.13.0)
# Requirement already satisfied: statsmodels in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (0.14.0)
# Requirement already satisfied: scipy in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (1.11.3)
# Requirement already satisfied: requests in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (2.31.0)
# Requirement already satisfied: matplotlib in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (3.7.1)
# Requirement already satisfied: numpy in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (1.24.3)
# Requirement already satisfied: scikit-learn in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (1.3.2)
# Requirement already satisfied: xmltodict in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (0.13.0)
# Requirement already satisfied: xlrd in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (2.0.1)
# Requirement already satisfied: pandas-datareader in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (0.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (4.12.2)
# Requirement already satisfied: pandas>=0.20 in /home/aleksi/.local/lib/python3.10/site-packages (from pyfinance) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas>=0.20->pyfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas>=0.20->pyfinance) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas>=0.20->pyfinance) (2023.3)
# Requirement already satisfied: soupsieve>1.2 in /home/aleksi/.local/lib/python3.10/site-packages (from beautifulsoup4->pyfinance) (2.5)
# Requirement already satisfied: packaging>=20.0 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib->pyfinance) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib->pyfinance) (4.39.4)
# Requirement already satisfied: cycler>=0.10 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib->pyfinance) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->pyfinance) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib->pyfinance) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aleksi/.local/lib/python3.10/site-packages (from matplotlib->pyfinance) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->pyfinance) (9.0.1)
# Requirement already satisfied: lxml in /home/aleksi/.local/lib/python3.10/site-packages (from pandas-datareader->pyfinance) (4.9.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aleksi/.local/lib/python3.10/site-packages (from requests->pyfinance) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->pyfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->pyfinance) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aleksi/.local/lib/python3.10/site-packages (from requests->pyfinance) (3.3.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/aleksi/.local/lib/python3.10/site-packages (from scikit-learn->pyfinance) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/aleksi/.local/lib/python3.10/site-packages (from scikit-learn->pyfinance) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/aleksi/.local/lib/python3.10/site-packages (from statsmodels->pyfinance) (0.5.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.2->statsmodels->pyfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in /home/aleksi/.local/lib/python3.10/site-packages (0.2.31)
# Requirement already satisfied: pytz>=2022.5 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: lxml>=4.9.1 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: requests>=2.31 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: multitasking>=0.0.7 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: html5lib>=1.1 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: peewee>=3.16.2 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: numpy>=1.16.5 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: pandas>=1.3.0 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (2.1.2)
# Requirement already satisfied: frozendict>=2.3.4 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: appdirs>=1.4.4 in /home/aleksi/.local/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in /home/aleksi/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: webencodings in /home/aleksi/.local/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/lib/python3/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aleksi/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31->yfinance) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aleksi/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yahoo-fin in /home/aleksi/.local/lib/python3.10/site-packages (0.8.9.1)
# Requirement already satisfied: feedparser in /home/aleksi/.local/lib/python3.10/site-packages (from yahoo-fin) (6.0.10)
# Requirement already satisfied: requests-html in /home/aleksi/.local/lib/python3.10/site-packages (from yahoo-fin) (0.10.0)
# Requirement already satisfied: pandas in /home/aleksi/.local/lib/python3.10/site-packages (from yahoo-fin) (2.1.2)
# Requirement already satisfied: requests in /home/aleksi/.local/lib/python3.10/site-packages (from yahoo-fin) (2.31.0)
# Requirement already satisfied: sgmllib3k in /home/aleksi/.local/lib/python3.10/site-packages (from feedparser->yahoo-fin) (1.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas->yahoo-fin) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas->yahoo-fin) (2023.3.post1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas->yahoo-fin) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aleksi/.local/lib/python3.10/site-packages (from pandas->yahoo-fin) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aleksi/.local/lib/python3.10/site-packages (from requests->yahoo-fin) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->yahoo-fin) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/aleksi/.local/lib/python3.10/site-packages (from requests->yahoo-fin) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->yahoo-fin) (1.26.5)
# Requirement already satisfied: bs4 in /home/aleksi/.local/lib/python3.10/site-packages (from requests-html->yahoo-fin) (0.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /home/aleksi/.local/lib/python3.10/site-packages (from requests-html->yahoo-fin) (1.0.2)
# Requirement already satisfied: pyquery in /home/aleksi/.local/lib/python3.10/site-packages (from requests-html->yahoo-fin) (2.0.0)
# Requirement already satisfied: fake-useragent in /home/aleksi/.local/lib/python3.10/site-packages (from requests-html->yahoo-fin) (1.3.0)
# Requirement already satisfied: parse in /home/aleksi/.local/lib/python3.10/site-packages (from requests-html->yahoo-fin) (1.19.1)
# Requirement already satisfied: w3lib in /home/aleksi/.local/lib/python3.10/site-packages (from requests-html->yahoo-fin) (2.1.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /home/aleksi/.local/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (4.65.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /home/aleksi/.local/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (8.2.2)
# Requirement already satisfied: websockets<11.0,>=10.0 in /home/aleksi/.local/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (10.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/lib/python3/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (4.6.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->yahoo-fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /home/aleksi/.local/lib/python3.10/site-packages (from bs4->requests-html->yahoo-fin) (4.12.2)
# Requirement already satisfied: cssselect>=1.2.0 in /home/aleksi/.local/lib/python3.10/site-packages (from pyquery->requests-html->yahoo-fin) (1.2.0)
# Requirement already satisfied: lxml>=2.1 in /home/aleksi/.local/lib/python3.10/site-packages (from pyquery->requests-html->yahoo-fin) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /home/aleksi/.local/lib/python3.10/site-packages (from beautifulsoup4->bs4->requests-html->yahoo-fin) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import packages

# %%
# Import needed stuff
import sys
import pyarrow.feather as feather
import math
import pandas
import numpy as np
import matplotlib.pyplot as plt
from pyfinance.options import BSM
import yfinance as yf
from datetime import datetime, timedelta, date
from yahoo_fin import options as op

# %% [markdown]
# # Delta Hedging experiment from YouTube video

# %%
# General Delta-hedging function
def number_of_shares_to_buy(shares_per_contract, number_of_options, delta_of_option):
    delta_of_underlying = 1 # why?

    # Delta-hedging says:
    # number_of_shares * delta_of_underlying + number_of_options * delta_of_option = 0
    number_of_shares = (-number_of_options * delta_of_option / delta_of_underlying ) * shares_per_contract

    print("To delta-hedge the portoflio, you need to",("buy" if number_of_shares >= 0 else "sell"), round(np.abs(number_of_shares),2), "shares.")
    return number_of_shares

# %%
# General volatility function
def get_volatility(stock_data):
    log_returns = np.log(stock_data/stock_data.shift(1)).dropna()
    volatility = log_returns.rolling(window = 21).std() * np.sqrt(252)
    return volatility

# %%
# General plot function
def plot_stock_price_and_volatility(stock_prices, volatility):
    fig, ax = plt.subplots()
    ax.plot(stock_prices, color='red')
    ax.set_xlabel('Date', fontsize = 14)
    ax.set_ylabel('Underlying price', color='red', fontsize = 14)
    
    ax2 = ax.twinx()
    ax2.plot(volatility, color = 'blue')
    ax2.set_ylabel('Volatility', color = 'blue', fontsize = 14)
    
    plt.show()

# %% [markdown]
# # Plot and hedge Apple stock data

# %%
# Read data and show it, data is from Refinitiv workspace
apple_stock_data_as_df = feather.read_feather('../data/fe2.feather')

# Set date to index instead of running index from 1..n
date_as_index = apple_stock_data_as_df.set_index('Date', inplace=False)

vola = get_volatility(date_as_index['Underlying'])

# Set values
shares_per_contract = 100 # How this is determined ?

number_of_options = 1 # How this is determined? 1 stock = 1 option, n stocks = n options?

# Use Black-Scholes model to compute the delta of the call option
# T = maturity and r = interest rate just thrown there, no spesific reason I guess to be those
call_delta = BSM(kind='call', S0=date_as_index['Underlying'].iloc[-1], K=date_as_index['Underlying'].iloc[-1], T=0.25, r=0.05, sigma=vola.iloc[-1]).delta()

# Delta of the call option is always positive and between 0 and 1
print("Delta of the call option:", call_delta)

# Use Black-Scholes model to compute the delta of the put option
# Again T = maturity and r = interest rate are just thrown there, no spesific reason to be those (I think)
put_delta = BSM(kind='put', S0=date_as_index['Underlying'].iloc[-1], K=date_as_index['Underlying'].iloc[-1], T=0.25, r=0.05, sigma=vola.iloc[-1]).delta()

# Delta of the put option is always negative and between 0 and -1
print("Delta of the put option:", put_delta)

# Get the amounts to balance, aka delta-hedge the portfolio
how_many_shares_to_sell = number_of_shares_to_buy(shares_per_contract, number_of_options, call_delta)

how_many_shares_to_buy = number_of_shares_to_buy(shares_per_contract, number_of_options, put_delta)

plot_stock_price_and_volatility(date_as_index['Underlying'], vola)
# Out:
# Delta of the call option: 0.56291693680677
# Delta of the put option: -0.43708306319323
# To delta-hedge the portoflio, you need to sell 56.29 shares.
# To delta-hedge the portoflio, you need to buy 43.71 shares.

# %% [markdown]
# # Plot and hedge SP500 data

# %%
stock_name = 'SPY'
years = 1
stock_data = yf.download(tickers = stock_name, start = datetime.today() - timedelta(days=years*365), end = datetime.today())

stock_data # Date as index, Open, High, Low, Close, Adj Close, Volume

stock_prices = stock_data['Adj Close'] # Closing prices
spy_vola = get_volatility(stock_prices)
plot_stock_price_and_volatility(stock_prices, spy_vola)

# Set values
shares_per_contract = 100 # How this is determined ?

number_of_options = 1 # How this is determined? 1 stock = 1 option, n stocks = n options?

# Use Black-Scholes model to compute the delta of the call option
# T = maturity and r = interest rate just thrown there, no spesific reason I guess to be those
call_delta = BSM(kind='call', S0=stock_prices.iloc[-1], K=stock_prices.iloc[-1], T=0.25, r=0.05, sigma=spy_vola.iloc[-1]).delta()

# Delta of the call option is always positive and between 0 and 1
print("Delta of the call option:", call_delta)

# Use Black-Scholes model to compute the delta of the put option
# Again T = maturity and r = interest rate are just thrown there, no spesific reason to be those (I think)
put_delta = BSM(kind='put', S0=stock_prices.iloc[-1], K=stock_prices.iloc[-1], T=0.25, r=0.05, sigma=spy_vola.iloc[-1]).delta()

# Delta of the put option is always negative and between 0 and -1
print("Delta of the put option:", put_delta)

# Get the amounts to balance, aka delta-hedge the portfolio
how_many_shares_to_sell = number_of_shares_to_buy(shares_per_contract, number_of_options, call_delta)

how_many_shares_to_buy = number_of_shares_to_buy(shares_per_contract, number_of_options, put_delta)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Delta of the call option: 0.5783356271143851
# Delta of the put option: -0.42166437288561487
# To delta-hedge the portoflio, you need to sell 57.83 shares.
# To delta-hedge the portoflio, you need to buy 42.17 shares.

# %% [markdown]
# # Experiment fetching financial data through Yahoo_fin

# %%
# Another viable dataset
def fetch_sp500_yahoofin():
    ticker = 'SPY'
    expiration_dates = op.get_expiration_dates(ticker)
    exp = pandas.DataFrame(expiration_dates)
    # print(exp)
    calls = op.get_calls(ticker, date = expiration_dates[13]) # Chose 29.12.2023 
    c = pandas.DataFrame(calls)
    print(c)
    
    long_position_in_call = c.iloc[0]
    print(long_position_in_call)
    print(long_position_in_call['Strike'])
    
    #puts = op.get_puts(ticker, date = expiration_dates[14])
    #print(puts)
    #chain_data = op.get_options_chain(ticker, date=expiration_dates[14])
    #print(chain_data)
